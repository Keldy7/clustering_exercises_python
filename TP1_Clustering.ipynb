# %%
# Importation des librairies

import matplotlib.pyplot as plt
from sklearn.datasets import load_iris # Chargement du dataset Iris
from sklearn.decomposition import PCA # Décomposition en analyse en composantes principales
from sklearn.preprocessing import StandardScaler

# %%
# Chargement et affichage   
iris = load_iris()

# %%
# Séparation des caractéristiques (X) et des étiquettes (y)
X = iris.data 
y = iris.target
print(f"Nombre d'observations : {X.shape[0]}")
print(f"Nombre de variables : {X.shape[1]}")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k')
# Out:
# Nombre d'observations : 150
# Nombre de variables : 4

# %%
# Standardisation des données
X_scaled = StandardScaler().fit_transform(X)

# %%
# Initialisation de l'ACP avec 2 composantes principales et transformation des donées
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_scaled)

# %%
# Visualisation des résultats à l'aide d'un nuage de points
plt.figure()
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.xlabel('Prémière composante principale ')
plt.ylabel('Deuxième composante principale')
plt.title("VisualiSation de l'ACP")
plt.colorbar()
plt.show()
